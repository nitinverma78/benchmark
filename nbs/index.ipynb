# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#| hide
from benchmark import bench
from nbdev.showdoc import *

# %% [markdown]
# # benchmark
#
# > Benchmark run-time performance of various sorting and searching algorithms across different data size and distributions on various compute paradigms

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install benchmark
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# benchmark sort algorithms in '../sort' folder on arrays of size 10, 1000 with data pulled from range and integer based distributions:

# %%
bench.main('../sort', data_sizes=[10, 1000], dist_families=["range","int"])

# %% [markdown]
# benchmark all distributions

# %%
bench.main('../sort', data_sizes=[10**3])

# %% [markdown]
# benchmark search algorithms with target=1

# %%
bench.main('../search', data_sizes=[10], dist_families=["range","int"], target=1)

# %% [markdown]
# ## Other functions

# %%
show_doc(bench.gen)
# Out:
# ---
#
# [source](https://github.com/nitinverma78/benchmark/blob/main/benchmark/bench.py#LNone){target="_blank" style="float:right; font-size:smaller"}
#
# ### gen
#
# >      gen (fam:str|None=None, n:int=0, sd:int=0)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | fam | str \| None | None | distribution family |
# | n | int | 0 | array of size |
# | sd | int | 0 | random seed |
# | **Returns** | **np.ndarray \| list** |  | **generate data** |
