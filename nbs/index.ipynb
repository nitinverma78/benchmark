# %%
# %load_ext autoreload
# %autoreload 2

# %%
#| hide
from benchmark import bench

# %% [markdown]
# # benchmark
#
# > Benchmark run-time performance of various sorting and searching algorithms across different data size and distributions on various compute paradigms

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install benchmark
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# benchmark sort algorithms in '../sort' folder on arrays of size 10, 100 with data pulled from range and integer based distributions:

# %%
bench.main('../sort', data_sizes=[10, 1000], dist_families=["range","int"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 bench.main('../sort', data_sizes=[10, 1000], dist_families=["range","int"])
#
# File ~/Documents/Apps/GitEx/benchmark/benchmark/bench.py:152, in main(fldr, **kwargs)
#     149 "Benchmark and plot runtime performance of algorithms stored in `fldr`, and optionally provide additional prameters for the algorithm"
#     150 #benchmark('../search', target=1)
#     151 #benchmark('../sort')
# --> 152 benchmark(fldr, **kwargs)
#
# File ~/Documents/Apps/GitEx/benchmark/benchmark/bench.py:126, in benchmark(alg_fldr, data_sizes, dist_families, num_variations, **kwargs)
#     125 def benchmark(alg_fldr, data_sizes=[10], dist_families=["float","int","normal","lognormal","binomial","exponential","range"] , num_variations=1, **kwargs):
# --> 126     typ, algs, modul, fams, sds, szs = *_get_scope(alg_fldr, dist_families, num_variations), data_sizes
#     128     Dat = namedtuple('Dat',['fam', 'sz', 'sd'])
#     129     dats = [dat:=Dat(fam, sz, sd) for fam in fams for sz in szs for sd in sds]
#
# File ~/Documents/Apps/GitEx/benchmark/benchmark/bench.py:39, in _get_scope(fldr, dist_families, nV)
#      37 algs = get_algs(fldr, filter_file=alg_type)
#      38 sys.path.append(os.path.join(Path.cwd(), os.pardir, alg_type))
# ---> 39 modul = _get_moduls(algs, fldr)
#      40 #distributions of data that need to be sorted
#      41 fams = [d for d in dist_families if d in ["float","int","normal","lognormal","binomial","exponential","range"]]
#
# File ~/Documents/Apps/GitEx/benchmark/benchmark/bench.py:27, in _get_moduls(algs, fldr)
#      25 def _get_moduls(algs, fldr):
#      26     modul = {}
# ---> 27     with working_directory(fldr):
#      28         for alg in algs:
#      29             modul[alg] = importlib.import_module(alg)
#
# File ~/opt/anaconda3/envs/Test/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/Test/lib/python3.10/site-packages/fastcore/foundation.py:21, in working_directory(path)
#      19 "Change working directory to `path` and return to previous on exit."
#      20 prev_cwd = Path.cwd()
# ---> 21 os.chdir(path)
#      22 try: yield
#      23 finally: os.chdir(prev_cwd)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../sort'

# %% [markdown]
# benchmark all distributions

# %%
bench.main('../sort', data_sizes=[10**3])

# %% [markdown]
# benchmark search algorithms with target=1

# %%
bench.main('../search', data_sizes=[10], dist_families=["range","int"], target=1)
