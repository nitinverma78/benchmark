# %%
#| default_exp sort

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
from benchmark import bench
from fastcore.meta import delegates
from inspect import signature as sig
from fastcore.script import call_parse

# %%
#| export
@delegates(bench.benchmark)
#def _main(target=1,**kwargs):
def _main(**kwargs):
    " customized main for sort " 
    return bench.benchmark(fldr='../sort', **kwargs)
    #return bench.benchmark(fldr='../search', **kwargs)
sig(_main)
#_main(data_sizes=[10, 1000], dist_families=["range","int"])
# Out:
# <Signature (*, data_sizes=[10], dist_families=['float', 'int', 'normal', 'lognormal', 'binomial', 'exponential', 'range'], num_variations=1)>

# %%
#| export
@call_parse
def main(data_size:int=10, #data size
         dist_fam:str="range", #data distributions
         num_variations:int=1, #data variations
         )->None:
    "plot run-times for sort algorithms"
    return _main(data_sizes=[data_size], dist_families=[dist_fam])

# %%
show_doc(main)
# Out:
# ---
#
# [source](https://github.com/nitinverma78/benchmark/blob/main/benchmark/sort.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### main
#
# >      main (data_size:int=10, dist_fam:str='range', num_variations:int=1)
#
# plot run-times for sort algorithms
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | data_size | int | 10 | data size |
# | dist_fam | str | range | data distributions |
# | num_variations | int | 1 | data variations |
# | **Returns** | **None** |  |  |

# %%
main()

# %% [markdown]
# # cli
# > This is how sort algs can be called via cli

# %% [markdown]
# ### illustration of cli

# %%
# %%bash
# python3 -m benchmark.sort --dist_fam "normal"
# Out:
# Figure(640x480)

# %%
#| hide
import nbdev; nbdev.nbdev_export()
